# %%
import community as community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import networkx as nx

from theorem_database import TheoremDatabase

# %% [markdown]
# https://github.com/taynaud/python-louvain
#
# https://python-louvain.readthedocs.io/en/latest/

# %%
# load the karate club graph
#G = nx.karate_club_graph()

th = tdb["opoeALTV"]

edges = [(s, t) for (s,t,_) in th["hyps"]]

theorems = {s["step"]:s["theorem"] for s in th["steps"]}

G = nx.Graph()
G.add_edges_from(edges)


#first compute the best partition
partition = community_louvain.best_partition(G)

# compute the best partition
partition = community_louvain.best_partition(G)

# draw the graph
pos = nx.spring_layout(G)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
#nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=40,cmap=cmap, node_color=list(partition.values()))
#nx.draw_networkx_edges(G, pos, alpha=0.5)
#plt.show()

plt.figure(figsize=(20,20))

nx.draw_networkx(G, pos, labels=theorems, cmap=cmap, node_color=list(partition.values()))

# %%
[] 1 - dfss ⊢ (𝐴 ⊆ 𝐵 ↔ 𝐴 = (𝐴 ∩ 𝐵)) - 13.2113

[] 2 - df-in ⊢ (𝐴 ∩ 𝐵) = {𝑥 ∣ (𝑥 ∈ 𝐴 ∧ 𝑥 ∈ 𝐵)} - 0

[2] 3 - eqeq2i ⊢ (𝐴 = (𝐴 ∩ 𝐵) ↔ 𝐴 = {𝑥 ∣ (𝑥 ∈ 𝐴 ∧ 𝑥 ∈ 𝐵)}) - 14.15841

[] 4 - abeq2 ⊢ (𝐴 = {𝑥 ∣ (𝑥 ∈ 𝐴 ∧ 𝑥 ∈ 𝐵)} ↔ ∀𝑥(𝑥 ∈ 𝐴 ↔ (𝑥 ∈ 𝐴 ∧ 𝑥 ∈ 𝐵))) - 18.86225

[1,3,4] 5 - 3bitri ⊢ (𝐴 ⊆ 𝐵 ↔ ∀𝑥(𝑥 ∈ 𝐴 ↔ (𝑥 ∈ 𝐴 ∧ 𝑥 ∈ 𝐵))) - 9.64562

[] 6 - pm4.71 ⊢ ((𝑥 ∈ 𝐴 → 𝑥 ∈ 𝐵) ↔ (𝑥 ∈ 𝐴 ↔ (𝑥 ∈ 𝐴 ∧ 𝑥 ∈ 𝐵))) - 10.77157

[6] 7 - albii ⊢ (∀𝑥(𝑥 ∈ 𝐴 → 𝑥 ∈ 𝐵) ↔ ∀𝑥(𝑥 ∈ 𝐴 ↔ (𝑥 ∈ 𝐴 ∧ 𝑥 ∈ 𝐵))) - 8.01533

[5,7] 8 - bitr4i ⊢ (𝐴 ⊆ 𝐵 ↔ ∀𝑥(𝑥 ∈ 𝐴 → 𝑥 ∈ 𝐵)) - 9.28052

# %%
labels = {n:n for n in G.nodes}
labels
# Out:
# {'3': '3',
#  '2': '2',
#  '5': '5',
#  '1': '1',
#  '4': '4',
#  '7': '7',
#  '6': '6',
#  '8': '8'}

# %%
tdb = TheoremDatabase("tdb")

# %%
theorems = {s["step"]:s["theorem"] for s in tdb["dfss2"]["steps"]}
theorems
# Out:
# {'1': 'dfss',
#  '2': 'df-in',
#  '3': 'eqeq2i',
#  '4': 'abeq2',
#  '5': '3bitri',
#  '6': 'pm4.71',
#  '7': 'albii',
#  '8': 'bitr4i'}

# %%
# Out:
# [('3', '2'),
#  ('5', '1'),
#  ('5', '3'),
#  ('5', '4'),
#  ('7', '6'),
#  ('8', '5'),
#  ('8', '7')]

# %%
G = nx.DiGraph()
G.add_edges_from(edges)

# %%
G
